# %% [markdown]
# # Sarsa
# - 価値反復法のアルゴリズムの一つ。
# - 行動価値を行が状態s、列が行動aとして定義する。
# - 各時刻での行動aを行動価値関数Qから求める方策を実装する。（Qの値が最大となる行動を採用する）
# - ただし、正しいQが定まっていない状態でこの方策を採用すると初期値に応じて行動が確定してしまうため、
# - 一定の確率εでランダムに行動する作戦をとる。（ε-greedy法）

# %%
# 使用するパッケージの宣言
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [1.5], marker="o", color='g', markersize=60)

# %%
# 初期の方策を決定するパラメータtheta_0を設定
# 方策　エージェントがどのように行動するかを決めたルール
# pi_theta(s, a)
# 状態sの時に行動aを採用する確率はパラメータthetaで決まる方策piに従う。

# 表形式表現　行が状態、列が行動aを示し、値はその行動を採用する確率
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
# columns ========> [up    . right , down  , left  ]
theta_0 = np.array([[np.nan, 1     , 1     , np.nan],  # s0
                    [np.nan, 1     , np.nan, 1     ],  # s1
                    [np.nan, np.nan, 1     , 1     ],  # s2
                    [1     , 1     , 1     , np.nan],  # s3
                    [np.nan, np.nan, 1     , 1     ],  # s4
                    [1     , np.nan, np.nan, np.nan],  # s5
                    [1     , np.nan, np.nan, np.nan],  # s6
                    [1     , 1     , np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義


def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    m, n = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)
pi_0
# Out:
# array([[0.        , 0.5       , 0.5       , 0.        ],
#        [0.        , 0.5       , 0.        , 0.5       ],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [0.33333333, 0.33333333, 0.33333333, 0.        ],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [0.5       , 0.5       , 0.        , 0.        ]])

# %%
# 初期の行動価値関数Qを設定

a, b = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0
# * theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる
Q
# Out:
# array([[       nan, 0.54034557, 0.31067873,        nan],
#        [       nan, 0.06741017,        nan, 0.77511607],
#        [       nan,        nan, 0.62217027, 0.07031575],
#        [0.08933881, 0.5906287 , 0.58326885,        nan],
#        [       nan,        nan, 0.58683213, 0.85030262],
#        [0.34569049,        nan,        nan,        nan],
#        [0.0500858 ,        nan,        nan,        nan],
#        [0.04974043, 0.42233924,        nan,        nan]])

# %%
# ε-greedy法を実装


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 行動をindexに
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 行動aの方向

    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return s_next

# %%
# Sarsaによる行動価値関数Qの更新


def Sarsa(s, a, r, s_next, a_next, Q, eta, gamma):

    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] - Q[s, a])

    return Q

# %%
# Sarsaで迷路を解く関数の定義、状態と行動の履歴および更新したQを出力


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while True:  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Sarsa(s, a, r, s_next, a_next, Q, eta, gamma)

        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Sarsaで迷路を解く

eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1

while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Sarsaで迷路を解き、移動した履歴と更新したQを求める
    s_a_history, Q = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値の変化を出力
    v = new_v

    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.5399075002409262
# 迷路を解くのにかかったステップ数は38です
# エピソード:2
# 0.6011121629607786
# 迷路を解くのにかかったステップ数は86です
# エピソード:3
# 0.7005767335156575
# 迷路を解くのにかかったステップ数は116です
# エピソード:4
# 1.6111009239550877
# 迷路を解くのにかかったステップ数は564です
# エピソード:5
# 0.11629037859186192
# 迷路を解くのにかかったステップ数は32です
# エピソード:6
# 0.07971149927483834
# 迷路を解くのにかかったステップ数は12です
# エピソード:7
# 0.09212505547051525
# 迷路を解くのにかかったステップ数は20です
# エピソード:8
# 0.05742349314383821
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.06883549007869133
# 迷路を解くのにかかったステップ数は10です
# エピソード:10
# 0.06768602339935059
# 迷路を解くのにかかったステップ数は10です
# エピソード:11
# 0.05416358916854175
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.06544760923759035
# 迷路を解くのにかかったステップ数は10です
# エピソード:13
# 0.052531999210840896
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.05086284569438049
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.05035141465211457
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.04978355586673805
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.04915688654904016
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.04847032212968061
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.047723976792670375
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.04691904107620043
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.046057646727266366
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.04514272656596885
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.04417787514750221
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.043167214427013156
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.042115267368992126
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.041026841443272566
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.03990692316737299
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.038760584250656094
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.0375928994367164
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.03640887579911889
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.035213392999185855
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.03401115384396075
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.03280664437201691
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.03160410263143565
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.03040749528738923
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.0292205011976035
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.02804650111544632
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.026888572716795955
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.025749490193552604
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.024631727710054174
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.023537466075862268
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.0224686020471504
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.021426759727579126
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.020413303596781507
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.01942935274949631
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.018475795980313903
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.01755330739752825
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.016662362294459276
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.015803253047716126
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.014976104849215188
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.014180891112399063
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.013417448423196032
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.01268549093295146
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.01198462411407808
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.011314357819731669
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.010674118606641803
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.010063261295557235
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.009481079756817556
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.008926816919576308
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.008399674012369296
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.007898819050252803
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.0074233945898321
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.006972524778301903
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.006545321726324493
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.006140891237300217
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.005758337927483703
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.005396769772580079
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.005055302117043747
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.004733061182368381
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.004429187110314259
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.004142836576331521
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.0038731850074593677
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.0036194284378074926
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.003380785033359701
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.00315649631637116
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.002945828118060323
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.002748071286684972
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.00256254217644325
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0023885829410001946
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.0022255616537999456
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.002072872275733828
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.0019299344891656744
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0017961934158210457
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.0016711192345917336
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0015542067139382443
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.0014449746722549062
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.001342965378326233
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.0012477439028445447
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.001158897430855177
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.001076034543986859
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.0009987844803714951
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.000926796379278505
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.0008597385166788651
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.0007972975372037006
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0007391776872788247
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.0006851000535844642
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.0006348018104217479
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.0005880354790438469
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 0.0005445682015369213
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 0.0005041810314122541
# 迷路を解くのにかかったステップ数は4です
