# %% [markdown]
# # Note
# この章では方策反復法を実装する。
#
# ##  方策反復法
# 方策にしたがってゴールにたどり着いた時に早くゴールできたケースで実行した行動は重要だと考え、
# その行動を今後多く取り入れるように方策を更新する
# ## 価値反復法
# ゴールから逆算してゴールの一つ手前、二つ手前とエージェントを誘導していく方法
# 状態に価値（優先度）をつける。

# %%
import matplotlib.pyplot as plt

# %%
# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在地S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)
# Out:
# /Users/shinnosuke.yata/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
# 初期の方策を決定するパラメータtheta_0を設定
# 方策　エージェントがどのように行動するかを決めたルール
# pi_theta(s, a)
# 状態sの時に行動aを採用する確率はパラメータthetaで決まる方策piに従う。

# 表形式表現　行が状態、列が行動aを示し、値はその行動を採用する確率
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
################### [up    . right , down  , left  ]
theta_0 = np.array([[np.nan, 1     , 1     , np.nan],  # s0
                    [np.nan, 1     , np.nan, 1     ],  # s1
                    [np.nan, np.nan, 1     , 1     ],  # s2
                    [1     , 1     , 1     , np.nan],  # s3
                    [np.nan, np.nan, 1     , 1     ],  # s4
                    [1     , np.nan, np.nan, np.nan],  # s5
                    [1     , np.nan, np.nan, np.nan],  # s6
                    [1     , 1     , np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %%
# 方策パラメータthetaを行動方策piにソフトマックス関数で変換する手法の定義
# 最初の値は単純な割合と同じであるが、thetaを更新していくと値が変わる。

def softmax_convert_into_pi_from_theta(theta):
    '''ソフトマックス関数で割合を計算する'''

    beta = 1.0
    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))

    exp_theta = np.exp(beta * theta)  # thetaをexp(theta)へと変換

    for i in range(0, m):
        # pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        # simpleに割合の計算の場合

        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        # softmaxで計算の場合

    pi = np.nan_to_num(pi)  # nanを0に変換

    return pi

# %%
# 初期の方策pi_0を求める
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
# 行動aと1step移動後の状態sを求める関数を定義


def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    # pi[s,:]の確率に従って、directionが選択される
    next_direction = np.random.choice(direction, p=pi[s, :])

    if next_direction == "up":
        action = 0
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる

    return action, s_next

# %%
# 迷路を解く関数の定義、状態と行動の履歴を出力


def goal_maze_ret_s_a(pi):
    s = 0  # スタート地点
    s_a_history = [[0, np.nan]]  # [[state, action]]

    while True:  # ゴールするまでループ
        action, next_s = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        # 現在の状態（つまり一番最後なのでindex=-1）の行動を代入

        s_a_history.append([next_s, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        if next_s == 8:  # ゴール地点なら終了
            break
        else:
            s = next_s

    return s_a_history

# %%
# 初期の方策で迷路を解く
s_a_history = goal_maze_ret_s_a(pi_0)
print(s_a_history)
print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")
# Out:
# [[0, 2], [3, 1], [4, 2], [7, 0], [4, 2], [7, 0], [4, 3], [3, 0], [0, 2], [3, 2], [6, 0], [3, 1], [4, 3], [3, 1], [4, 2], [7, 1], [8, nan]]
# 迷路を解くのにかかったステップ数は16です

# %%
# thetaの更新関数を定義します


def update_theta(theta, pi, s_a_history):
    eta = 0.1 # 学習率
    T = len(s_a_history) - 1  # ゴールまでの総ステップ数

    m, n = theta.shape  # thetaの行列サイズを取得
    delta_theta = theta.copy()  # Δthetaの元を作成、ポインタ参照なので、delta_theta = thetaはダメ

    # delta_thetaを要素ごとに求めます
    for i in range(m):
        for j in range(n):
            if not(np.isnan(theta[i, j])):  # thetaがnanでない場合

                SA_i = [SA for SA in s_a_history if SA[0] == i] # type: List[float]
                # 履歴から状態iのものを取り出すリスト内包表記です

                SA_ij = [SA for SA in s_a_history if SA == [i, j]] # type: List[float]
                # 状態iで行動jをしたものを取り出す

                N_i = len(SA_i)  # 状態iで行動した総回数
                N_ij = len(SA_ij)  # 状態iで行動jをとった回数
                
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T
    
    new_theta = theta + eta * delta_theta

    return new_theta

# %%
# 方策の更新
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.49687504 0.50312496 0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33194156 0.33611687 0.33194156 0.        ]
#  [0.         0.         0.50156249 0.49843751]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.50156249 0.49843751 0.         0.        ]]

# %%
# 方策勾配法で迷路を解く

stop_epsilon = 10**-4  # 10^-4よりも方策に変化が少なくなったら学習終了とする


theta = theta_0
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
pi = pi_0

is_continue = True

while is_continue:  # is_continueがFalseになるまで繰り返す
    s_a_history = goal_maze_ret_s_a(pi)  # 方策πで迷路内を探索した履歴を求める
    new_theta = update_theta(theta, pi, s_a_history)  # パラメータΘを更新
    new_pi = softmax_convert_into_pi_from_theta(new_theta)  # 方策πの更新

    print("方策の変化量は{}".format(np.sum(np.abs(new_pi - pi))))  # 方策の変化を出力
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        print("変化量がイプシロンよりも小さくなりました。")
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
# Out:
# 方策の変化量は0.016208616389706332
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.009870148356782793
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.018897283004537857
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.005902359411621982
# 迷路を解くのにかかったステップ数は34です
# 方策の変化量は0.009230027870411439
# 迷路を解くのにかかったステップ数は118です
# 方策の変化量は0.024739705489757846
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.007797857826300603
# 迷路を解くのにかかったステップ数は112です
# 方策の変化量は0.010773045440249873
# 迷路を解くのにかかったステップ数は84です
# 方策の変化量は0.0066636221309660515
# 迷路を解くのにかかったステップ数は84です
# 方策の変化量は0.03132092521855867
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.0161831106417466
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.020630780823163775
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.014555501340189791
# 迷路を解くのにかかったステップ数は116です
# 方策の変化量は0.032198305234422187
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008353530290985234
# 迷路を解くのにかかったステップ数は56です
# 方策の変化量は0.02491212031565948
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.018689626853997388
# 迷路を解くのにかかったステップ数は48です
# 方策の変化量は0.017536018111906804
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.020164599990370513
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.006445994207482486
# 迷路を解くのにかかったステップ数は44です
# 方策の変化量は0.010273541582610624
# 迷路を解くのにかかったステップ数は42です
# 方策の変化量は0.04742345215588395
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010720969870845032
# 迷路を解くのにかかったステップ数は52です
# 方策の変化量は0.0064412159815546155
# 迷路を解くのにかかったステップ数は58です
# 方策の変化量は0.008072787958317784
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.01717932693547969
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.007515673684160118
# 迷路を解くのにかかったステップ数は50です
# 方策の変化量は0.007482370607804267
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.010439135779403919
# 迷路を解くのにかかったステップ数は44です
# 方策の変化量は0.01501845434848631
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.03244296411812331
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013859173683396675
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.019881131049007683
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.011075810030481359
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.019973659290409618
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.01227909573936381
# 迷路を解くのにかかったステップ数は72です
# 方策の変化量は0.008178862465198167
# 迷路を解くのにかかったステップ数は122です
# 方策の変化量は0.016826037177384567
# 迷路を解くのにかかったステップ数は26です
# 方策の変化量は0.011604737373731744
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.005054590665207803
# 迷路を解くのにかかったステップ数は104です
# 方策の変化量は0.013900933539956195
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.011617327867456395
# 迷路を解くのにかかったステップ数は68です
# 方策の変化量は0.020407100423918023
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.03260710991604998
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.010182464074223463
# 迷路を解くのにかかったステップ数は56です
# 方策の変化量は0.02325068127747476
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.011708163910683855
# 迷路を解くのにかかったステップ数は32です
# 方策の変化量は0.0308029981686867
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.036981881054587995
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.009763990756075536
# 迷路を解くのにかかったステップ数は42です
# 方策の変化量は0.016774559864893568
# 迷路を解くのにかかったステップ数は36です
# 方策の変化量は0.029939596565741355
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01724665864914765
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.015003230791250988
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.00839460193447028
# 迷路を解くのにかかったステップ数は58です
# 方策の変化量は0.011211168749826417
# 迷路を解くのにかかったステップ数は40です
# 方策の変化量は0.02197631490733115
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.017668050401921542
# 迷路を解くのにかかったステップ数は46です
# 方策の変化量は0.03627029998291248
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.02419311040391514
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.011478545825702013
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.015376190925756206
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.017099182438979288
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.02484926484547273
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.021584169287933053
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.00978382247564874
# 迷路を解くのにかかったステップ数は32です
# 方策の変化量は0.015712426793216383
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.016185130545296245
# 迷路を解くのにかかったステップ数は64です
# 方策の変化量は0.013569182117837253
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.008560996043343372
# 迷路を解くのにかかったステップ数は64です
# 方策の変化量は0.02243117149394991
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.007969937380197467
# 迷路を解くのにかかったステップ数は70です
# 方策の変化量は0.022169790675931222
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.007150711006710109
# 迷路を解くのにかかったステップ数は54です
# 方策の変化量は0.028856115212347377
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.017551084681233398
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.012101828095994749
# 迷路を解くのにかかったステップ数は42です
# 方策の変化量は0.017695260311173966
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.0299202266255561
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.015722674639431222
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.021623189745397897
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014565789430913412
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.019664287207725006
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.03280260839377669
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.019857406992894677
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.019699371497387375
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.03740627655839002
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014693012857913856
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.018065780771147233
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.025809699580706114
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.013858830953062229
# 迷路を解くのにかかったステップ数は26です
# 方策の変化量は0.041975976383647695
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013461176111804307
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.022040021455795422
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.012417723624283339
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.01910594312195396
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.02283578168469269
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.019684299345868905
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.00987333947884561
# 迷路を解くのにかかったステップ数は34です
# 方策の変化量は0.03244403950620972
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.028912135490774094
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.031900390704791226
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.03034661899783414
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01984461496709722
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.009806981278045579
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.022791747294897413
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.019616206198554476
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.015316063090079268
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.01438974652025582
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.013815327257484078
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.012245603638935953
# 迷路を解くのにかかったステップ数は32です
# 方策の変化量は0.0161233814340756
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.011976911185944739
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.017971115594988096
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.012887957781050119
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.013801793342835877
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.013947175631368214
# 迷路を解くのにかかったステップ数は54です
# 方策の変化量は0.015535929199731846
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.014027546420828818
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.007599638938918851
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.014340149244130906
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.02584218260011789
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.015403882280880687
# 迷路を解くのにかかったステップ数は42です
# 方策の変化量は0.0399789846043776
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01830903736327516
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.01234284044775219
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.020807290947940926
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.021665813509284648
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.02183721591954285
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.009837397444948937
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.018228610152964453
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.02518787497671271
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0170792533608915
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.008593911528581522
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.029505187073901373
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.007251845543033597
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.011055974174311811
# 迷路を解くのにかかったステップ数は70です
# 方策の変化量は0.019139063107785292
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.02856602900511157
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.024156259724990414
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.016986645948210477
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.02496751167349376
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.03122399877193599
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.038092629259225186
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.028780356677784336
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.015841998031801585
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.020755442800460266
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.03493809642925755
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014479340078043579
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.017410776686053286
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.02706674343672033
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.029774536885739278
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.031101610406701785
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.009269636942862314
# 迷路を解くのにかかったステップ数は68です
# 方策の変化量は0.016512578871728578
# 迷路を解くのにかかったステップ数は40です
# 方策の変化量は0.02962100080308966
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.010147655025074198
# 迷路を解くのにかかったステップ数は70です
# 方策の変化量は0.012950963377362179
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.024922568234863884
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.025811464774365744
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.014841728107260255
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.022800963978547834
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.016446322287267834
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.010958806390905684
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.01197000200267484
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.010509219192345154
# 迷路を解くのにかかったステップ数は42です
# 方策の変化量は0.015574120683248066
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.02015685840284026
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.018578139617199896
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.02927565069340632
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.036678539425106876
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015926541325968407
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.03586023540420474
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.020462241489261013
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.015253363538092063
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.02301222692438154
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.03631166951385037
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009514868455560821
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.030923244722240867
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.021846701172388155
# 迷路を解くのにかかったステップ数は42です
# 方策の変化量は0.015726124380381512
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.01308773100312069
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.01841535507891312
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.025399240152382235
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00878155447744322
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.01504305910852241
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.03523914698339953
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.03473029701440841
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01199265841887015
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.028773081918971877
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.02534199530529954
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.02930215479310197
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.033780522497627474
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.02423188489989822
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.023872797369672155
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.016046612141472377
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.015806790974476126
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.017519513893128558
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.01543909190678619
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.03269686504630845
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.02308041161458388
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01641305907933599
# 迷路を解くのにかかったステップ数は48です
# 方策の変化量は0.010445486017961775
# 迷路を解くのにかかったステップ数は60です
# 方策の変化量は0.028359510963625767
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01431138164764667
# 迷路を解くのにかかったステップ数は52です
# 方策の変化量は0.013769394347384362
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.01594310428644502
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.019798957783808857
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.0183033174103977
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.01846402044206466
# 迷路を解くのにかかったステップ数は32です
# 方策の変化量は0.01999763674096941
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01353026737822402
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.031813045169724025
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013622048670885123
# 迷路を解くのにかかったステップ数は46です
# 方策の変化量は0.018117991864287586
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.02014920330828407
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.012699678822960109
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.026780376536524347
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.015524093636517022
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.028360056968953218
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.015744721561228303
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01921783647111633
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013302707916472811
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.02214800477715878
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.022997251697196047
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.021493622020038322
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018865706890176
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018708801167226202
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.019488676041900077
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.017430691808607235
# 迷路を解くのにかかったステップ数は36です
# 方策の変化量は0.018538453323935555
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.029690741934956327
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.020100101634932532
# 迷路を解くのにかかったステップ数は28です
# 方策の変化量は0.022069045146453165
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01130759140898735
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.018809767789755627
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.02276711002859294
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.021083465797385514
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014535653371852725
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.018602263504795463
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.018375007314716696
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.02847651270946777
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010438029366723306
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.01582490380071294
# 迷路を解くのにかかったステップ数は38です
# 方策の変化量は0.017351973006857924
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.027211386652930353
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.027199538460210337
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.015869506226076302
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.021331783864278142
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.017193710230374998
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.018201942844216584
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.027684941066202867
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.023452462419010056
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.02726977388796603
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.02687114526938761
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.027234098229991732
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.022103751369318858
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.02641445681794216
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.026440659449866538
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01369210609941357
# 迷路を解くのにかかったステップ数は26です
# 方策の変化量は0.016583410339415072
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018083038370816845
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.022053537340347096
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.017568908693812058
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.026045182699108743
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.023995040411766755
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.017272622845824565
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.024460697028663936
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.013678875079900343
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.01159792917617708
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.01482925392681786
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.018685854911395378
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.011588802564358236
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.01555603723361143
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.017439979475605355
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.026147527656602276
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011198795787647792
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.021540163488216413
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.016259294189393758
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018981638807591322
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01990497963993737
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.022752034259810705
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.018902571717033217
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.016105434606734498
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.025741715982526447
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014121973014207229
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.025718609574531953
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.025239143648380757
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.020969847532936375
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.015918450857874772
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.024903915715616204
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01924709213288589
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.02442433288494711
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.024066778390940458
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.017794991472328797
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.02467965496533045
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013441818254839921
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.018102038242145208
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.02513510414746939
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.020065266345411892
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.02372947979211265
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.024097556877035714
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.019358884331683618
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013667549983948812
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.014181529287269179
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.023334757362129976
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.022991084279577634
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.022652868422852995
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.022320062631659726
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016502648183419177
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.009224609020699992
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.022065948598232854
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.02174154564448602
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.022685057162004585
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018325704927511705
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.023569282682547404
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.02114323840496385
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012666829742706859
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.019218569632972388
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.019100331226548112
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.017833815306256384
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.021074563927242773
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01743478296030676
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.017681611645948364
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.020526303646699134
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015307514642995984
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.020278135017416793
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013118346831218819
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.013442181064954706
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.017155009365411422
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.014530722804068641
# 迷路を解くのにかかったステップ数は30です
# 方策の変化量は0.02006601253321072
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016974054931568255
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.016805254048691015
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.019696759530294206
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013157409188632674
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.020455546565689542
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.019403888577449208
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.019124929112441957
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016379003858310037
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.011357594540947452
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.026284092847403434
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.01662402742716082
# 迷路を解くのにかかったステップ数は24です
# 方策の変化量は0.017464666601348905
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01566735113550699
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.0160045512196971
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.019100194013032756
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.023194978974142882
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.021535829437169557
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.019001517078760466
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0187300132704864
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014864067353424965
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.016027898506920796
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.022385080026051413
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018436079612427936
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01865421926831967
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.017481078850595494
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.017449158814324905
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.010498488128612926
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.018384074620676316
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.018121325270337413
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014430754775010185
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.018005536696137386
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.018220451880083283
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.01446956843340913
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.015182269569824935
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.013449307666263233
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.017987878842021687
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.017732415052302247
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01589341633683597
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.01755018230832009
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016361703664700855
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.016423624927296154
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.021128369229177713
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.019985448921856358
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.019814576280779483
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.015069094777354158
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.012551235609860323
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.018290018659451318
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.01735120831867712
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01710603659602189
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01686508743163931
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015087074769256331
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.016654554976031494
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016420955710775897
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.018462515775126198
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.016227602261160406
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014918785209508512
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.016032082870345715
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016506618145012614
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.01593341876516452
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015713000526897614
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015496369807179694
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015345070989030318
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.015294701844462189
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01368804276963101
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.015122386994886855
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01475048762291764
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.011085455250403609
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.013245287731202399
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014561426235928043
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.015003846768247286
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014801116637309347
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016089585033536247
# 迷路を解くのにかかったステップ数は36です
# 方策の変化量は0.01586248602472362
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.014818635508433986
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.014458153940996588
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.013335060105497065
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.018126648997809136
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.015021050882206538
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.015646827285885956
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014891472654092741
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016217288260700152
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.014783916154976762
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014662047833006425
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.013921880754488525
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.020368923917289283
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014635440204790184
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014437968299188808
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01424385221626856
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01405303219870993
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013865449246602407
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012129948265662244
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010652383181767727
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01855416229602136
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.013467304946529174
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.013914363964335597
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016875345301432226
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.015807102501417536
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.01380013342775216
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014246486551721727
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.013744936855073914
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.019131359341767296
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01728563027180466
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.017362121951126297
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.018515857393930024
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.014025571357464406
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013837453719804993
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014659893331408158
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014030267937153118
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01372442768384502
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012348494640351537
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013490990566047939
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013312336063937918
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013136711961528796
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01765493653013686
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.019334710613866657
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013223369859937162
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.012099284202395477
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.012680536190488867
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.013161978664466029
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015590522226467063
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.013093438365604337
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014076512155664966
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.02335182638766123
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.012971173567044109
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01778925951413049
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.012872939446657988
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01270406736243157
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0158164758741276
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.012490453677526159
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01364363737982971
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014120585001384911
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.012371900124969998
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012211457120464453
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012053716839632328
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01527832063441048
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0118574574444551
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013311022361441882
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.011716859426355059
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011567073533914785
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011419800928791024
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011274994065546676
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009388587030448994
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.011227479960011402
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011085803375883552
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010946488211483876
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013427477131966153
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01797577845583337
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.010848438589456222
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010168696390465845
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.01506315608579327
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.01494116885943425
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.01792644353672014
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.016613427664475752
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.011044259858584177
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.011013355115613174
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011080085422819727
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.010940159546479297
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010804068282161655
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.017699147355487596
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.018715268456366563
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.010801984071694679
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010668096084771608
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010536403808122763
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010406865905714477
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012045439276883466
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.013763297968015703
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010392177323598165
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015858581279584366
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.013707745455895537
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.011557079224877045
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.010550852130730343
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010421595206420192
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010294427719571342
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008868048579170618
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009152988357662706
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010203171893934312
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.017041637824259964
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014229763486828223
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.01208615873991671
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010302438354361884
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010177220090150055
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010054014457636928
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009932784375373135
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009813493435095785
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009696105894197685
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01019679555824915
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009574601421183854
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009461111497762839
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016558426804857224
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.016504436974944442
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009369760000349017
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015585596752863515
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.008614120087526711
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013338603732783852
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.011762756195050766
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.009422641636441728
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009311219817236177
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010054972743534438
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.00854369608270926
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008526171194188997
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009292072104752205
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00918290111292959
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016668976928572915
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.008495034728020268
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.011608703354621414
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.009213705924142654
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008686915902870684
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.011628742577721563
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00849957749341873
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009173443916838553
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009066246196431413
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.016218863773346123
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008970024741355859
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.023029253392113633
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.008937688639330227
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008834228081096282
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008732367717374817
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008632078786662056
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014957123371932432
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.01122729129959485
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013720347296846458
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.008719250545218007
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008619065689090391
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008520426338639656
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008423304558196024
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014324401725091016
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.02464066661569045
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.00855295576767294
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008455329351419363
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012443638276199029
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.008412391278963663
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008316960037965587
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015728778731420923
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0094031687695834
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008242747757025201
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010903570009150265
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008173711081340768
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008081798362059828
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007991282535471517
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011720464985444504
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007875749726674972
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007788437097307685
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007702438649486637
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009562991381786151
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.010601657004309137
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007718386376260128
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01143661035483233
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00912286015432312
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007620097131808445
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0075365874985721115
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007454325263136274
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011216635158529734
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01283635125339233
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.007415251272711601
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011419796202663784
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.007418465191822682
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007338180622537868
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01119089885754769
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.02033137268870347
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.007353132339904825
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007273831520624691
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010319360811754733
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008965412368814207
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014866277399693914
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007275330041130845
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007197121418412208
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0071200661037513074
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0070441434571051065
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008875952131188941
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010195194986515665
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007031135839499103
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007714089803198709
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.010654025639380435
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010192598964987615
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007065196270641269
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00699002879651256
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014541949011194724
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007729090708046699
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007732969423021249
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014537388352687364
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0069943541126287895
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006920284759153003
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006847291998362259
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006775356855120915
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011353611371430108
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.006766187745394406
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.015222437364249011
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.009942273959793538
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006825762441544564
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009257435853234575
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.007689491136729704
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008604744820990023
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014255595203731902
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.006947145853478429
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006873564681633387
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008518746248132758
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007470725231771155
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006841773999316056
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00676974720640304
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013587664021541684
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.010655423045743559
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.022640071538121434
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.0067039872381638305
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006634147081459235
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010508264653509888
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.014190420822575475
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006570416826237838
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006502564814933706
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00838390706555242
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0064532889574400315
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006387102719351931
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006321850770227108
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006257517088575651
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006194085958197329
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006131541962368273
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01400373404315583
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.006140894490818796
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008184602950687209
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0060994094666496496
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01429612950855512
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.008223957673966428
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.006139340328799703
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006077522076942274
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009340618117072083
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006041459710002875
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005980920503466672
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01906875679784699
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.006032880668490337
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009818146627623106
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00825524104265786
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.014225507714684948
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.00993799735027591
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006064517709150452
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006003763847680532
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008216579226803133
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00713762941015543
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008181296460463519
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0060067451327516785
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005946800575174951
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007061106879384105
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0059122977383639225
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00704899397360588
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009846002061537573
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013441680622736957
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005890456079168785
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005832198335028821
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005774738227786083
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007967286978296892
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.01329813547314572
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005757786621614039
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009050071422218614
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005722830506932786
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005666812347587355
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00951670059462531
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00560917637832356
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01479728617966336
# 迷路を解くのにかかったステップ数は20です
# 方策の変化量は0.005560132010798732
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005506372704915316
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005453336571231204
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013591578716933145
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.00546749737720198
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005414989053539654
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005363183743130523
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005312069798685315
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00682575466715514
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.008713296532180989
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005309653519451521
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01179914325880621
# 迷路を解くのにかかったステップ数は22です
# 方策の変化量は0.0052785406501381915
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010516131804325146
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.014411955206529728
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.005302892505000864
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01103940125504986
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.005312092860199694
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005261613941658402
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005211803919422525
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005162651840434143
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008991998811518923
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005115418437393271
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005067577388510186
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008914964414291501
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005024155754393356
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013436810478723443
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.005021029819184647
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004974455929792232
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004928486754972067
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006573178122528667
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.009414011303753883
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.012781206976292425
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004983098734574323
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004936993668951492
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008325687409658486
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004912889881881599
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004867660790717293
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004823015524400495
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004778944698096352
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004735439101383923
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004692489694734958
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009249262679911482
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.00851508185749715
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.010224979629950559
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.017369618648105573
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.004812925360970305
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01294204899629288
# 迷路を解くのにかかったステップ数は18です
# 方策の変化量は0.004775574405456298
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007457967005184529
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00475530451272263
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00471215138603337
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0046695483781273445
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.030076353709161077
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.004635883014404166
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.018070558440748744
# 迷路を解くのにかかったステップ数は16です
# 方策の変化量は0.004619896853386901
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004578465547449576
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004537557215815724
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004497163590529582
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.014368638938371509
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.006367656890435031
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013077091312291358
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.004613645137047262
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008338622737622134
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.012673033682580798
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00460036543456388
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0045591935605938105
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004518541122193159
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004478399886871001
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01252995465507857
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007323756621369637
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004482496256797072
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004442798582552462
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004403596996449127
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0078289237153603
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004386665119894481
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004348135021556607
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0043100832460315625
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004272502312579585
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004235384878182605
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012850851004017366
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.004251565975209218
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0077145637048672555
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0042390299311602375
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007822419189795926
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.012237262344944586
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004232943076609069
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004196274613339629
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004160056590860967
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008557931583435832
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.0041389957598143845
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0041034712431862325
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0040683795835008
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007632339207375077
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004042846851872062
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010343095489137921
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0076311338944955315
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004088604255552616
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012093968873506972
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.012757637020417087
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.007717101417719377
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.007099821736396075
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004179184160355592
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0076457881407828165
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.013158228111581849
# 迷路を解くのにかかったステップ数は12です
# 方策の変化量は0.004162842242461912
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004126872719643529
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004091345838368704
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004056254670755058
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0076193316369294745
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0076700967780595625
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0040807791357150985
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006060704151560195
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0040629816261018165
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.004028131419728534
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013933029969736735
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0040116177400372904
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0075923878516078736
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.004008366866149221
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003974104936060943
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003940261877773299
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0039068311528425576
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0038738063449023988
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0072433880951683904
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0038491196137896075
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00381683260361107
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.01515227871814434
# 迷路を解くのにかかったステップ数は26です
# 方策の変化量は0.003814424023467787
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00378257654838509
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0073899183803722845
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005885255513516124
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0037988615835717193
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007414650116664097
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0037989444162111335
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0037671578735072875
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0037357528839962392
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0037047235821184507
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0036740642105191623
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011744970772304693
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006594610652459344
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.003681353349856996
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003651006308654031
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0036210181598381602
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007225251795720387
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.011679369735009715
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00364555045730193
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0057637441734633005
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.003632808755991576
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006546009226413879
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0057839215221347565
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.010168088177477913
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0037008053719966155
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0036701162674684096
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00363979265889193
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007244964055055203
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006908956550001635
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0036483636829930735
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003618261215280194
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0035885160503751692
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0035591227444003934
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00353007595320539
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008124744579368522
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0035457982441945216
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008414683064881835
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.003556823747357468
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011108776806960367
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0035709804137395024
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003541840967688656
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003513043376192293
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0034845824940838432
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0034564532692752253
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0034286507408273215
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003401170037054972
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.012017688881229553
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.003426709206861847
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0033992020808724793
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0033720131354085803
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003345137637633888
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006560455408565383
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.003325482328066752
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003299184199641987
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003273185843296056
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006892300789552684
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0032791184623396155
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006502403111089308
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.011120041009880996
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0032813576656952476
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0032555381535044683
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006130390120521766
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006893954747418211
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006183909125489703
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0032928728781676936
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006928199529759468
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00698675891923857
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00811436549598487
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.003345116306409844
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003318372581378369
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0032919384287684317
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0032658092204870953
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008079211727343862
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0032776890255761387
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0032517679865688917
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003226143472864304
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0032008111072250323
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0031757665905317797
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006818065249450993
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0031845965488924224
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0031596473901961547
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0031349817500449448
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003110595460364733
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007367481359761376
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.006031141683546994
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006843674775750638
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0031915196617234437
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003166413408574882
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006849046708533729
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0031775456428556684
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.011045900129454896
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.008406102613984709
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0069462055429452
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.003259228700952098
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0032332707369155736
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003207613511467554
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003182252508111501
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0031571832925924304
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006868307327416098
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0031692753785044353
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003144248189835906
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006873425495366833
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006014184943184925
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0031734654350156766
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009127275752358152
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.0031981873983126657
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003172742684929418
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003147593825347267
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0031227363438606354
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003098165847061407
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005293892811675617
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006853784062861239
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.003127952393102172
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.013215839801784555
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0031133177566849413
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.009957379585978407
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0031606249465718217
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00313539821192816
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0031104670969040044
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00308582707986671
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0030614737233726486
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.003037402672351225
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0030136096523383157
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0029900904677456
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007613712750783416
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.003012238050485491
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.006040723199677099
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00299520663428577
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0029719043042251495
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0029488685351648433
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002926095338204829
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002903580797339704
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002881321067904341
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007534397538832956
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0029048457769646485
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00670521889379732
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0029218185536254992
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0059713275364163265
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.005659240845560694
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0029208108404324834
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002898283374918341
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005658915909448052
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.002890462025033229
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0028683196386038792
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005972387782087495
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.002855293069460467
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002833590436630881
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.008678371744401038
# 迷路を解くのにかかったステップ数は14です
# 方策の変化量は0.002863697940881371
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002841988474276573
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.002820520497769617
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.010049545818411797
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.012905652720393776
# 迷路を解くのにかかったステップ数は8です
# 方策の変化量は0.0028386475027929597
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005649341765723806
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006042325958527162
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.006614011324358661
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.002877952608483919
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0028561527375484674
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.007784793089457981
# ...
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001305308977272105
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001302997560802023
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001300692359550229
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0011697343820865225
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00013157726833964642
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013134364147793579
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0012740739537054901
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0001331040775081893
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0013082254110112698
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00013499005985846343
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013474695192431697
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013450450788316838
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001342627252992161
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013402160174731323
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013378113481352788
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001335413220948864
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001333021612000447
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013306364974827352
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013282578536958495
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013258856570496497
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013235198840670474
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001321160511372054
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001318807515700189
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013164608738830928
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013141205628766812
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001311786559725671
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013094588415876914
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013071373857167536
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013048221694789315
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013025131703388836
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013002103658629229
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0013166601604022669
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0001319705305614146
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013173529490453223
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001315006952978693
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001312667294310916
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0011246414082299889
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00013269218563870255
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013245539303830163
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013221924062220385
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013198372606927807
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013174884706515684
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013151460130849356
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.005610226003008402
# 迷路を解くのにかかったステップ数は10です
# 方策の変化量は0.00013173649707481742
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001315027993618427
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013126972938826836
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013103728489165418
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013080546361848508
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013057426332592145
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013034368178180614
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013011371676331825
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001298843660579932
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001296556274638823
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001294274987876879
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012919997784670637
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012897306246863367
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012874675048953933
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012852103975622559
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001282959281251536
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001280714134615328
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012784749364097396
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0011277655664967464
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00012930446647909516
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012907756891613296
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0013181050864798042
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00013103476653660712
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001308028625783119
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013057157987151138
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00013034091618200662
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001301108692886143
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012988143697816382
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012965261704818778
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012942440730587777
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001291968055679507
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012896980966221883
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012874341742526857
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001285176267024797
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012829243535047476
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012806784123534087
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012784384223154567
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012762043622375867
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012739762110642282
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012717539478254714
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012695375516515
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012673270017717238
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012651222774755916
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012629233581915728
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012607302234025203
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0013170167607251
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00012805406715914354
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012782964249353178
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012760581378088408
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012738257889661694
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012715993572489856
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012693788216030025
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012671641610657002
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012649553547573397
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012627523819087015
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012605552218318897
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012583638539351988
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012561782577082126
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001253998412751884
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012518242987432163
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012496558954476315
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012474931827299515
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001245336140536079
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001243184748909703
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001241038987972818
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012388988379360977
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001236764279111055
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0012995152256838755
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00012560718160747886
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001253888094558224
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012517101300836032
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012495379022604662
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012473713907922707
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001245210575461092
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012430554361459942
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012409059528230293
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012387621055376385
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001236623874449269
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012344912397734518
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012323641818462114
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012302426810633683
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012281267179319565
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012260162730187013
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012239113269962507
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012218118606122097
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012197178547027586
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012176292901898249
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012155461480770763
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012134684094456359
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012113960554685325
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012093290673938911
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012072674265683862
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012052111143903525
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012031601123665796
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012011144020727081
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011990739651674374
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011970387833851875
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011950088385448594
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011929841125449085
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011909645873548792
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011889502450334113
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0012885341308968307
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.0001208151982351139
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012060887547598632
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012040308754056317
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00012019783256415374
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011999310869205936
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011978891407550367
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011958524687437355
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011938210525680275
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011917948739948933
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011897739148597486
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011877581570845022
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011857475826693512
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011837421736916702
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011817419123053702
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011797467807407765
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001177756761315072
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011757718364044031
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011737919884804472
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011718172000781298
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011698474538119306
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011678827323708188
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011659230185162572
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011639682950987003
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011620185450108428
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011600737512563325
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011581338968854812
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011561989650321625
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011542689388962732
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011523438017654354
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001150423536976572
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011485081279526826
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011465975581820623
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011446918112355958
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001142790870731717
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011408947203771919
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001139003343941028
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011371167252700008
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001135234848252814
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011333576968940336
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011314852552140979
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0012763163130892902
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00011506978940860682
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011487762725651343
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011468595285827297
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001144947645462975
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011430406066133443
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011411383954967359
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011392409956679193
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011373483907338271
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011354605643826288
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011335775003662105
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011316991825144167
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011298255947136092
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001127956720933139
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011260925451950232
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011242330516071479
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001122378224328209
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011205280475997705
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011186825057113957
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011168415830428886
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011150052640251928
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011131735331513029
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011113463749936985
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011095237741807346
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011077057154131736
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001105892183446179
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011040831631068532
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011022786392874719
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00011004785969365508
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001098683021070173
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001096891896770636
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001095105209178368
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001093322943502735
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001091545085003167
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010897716190116057
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010880025309156945
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010862378061757272
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001084477430289138
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010827213888400453
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010809696674541833
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010792222518287049
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.001019890471747489
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00010912274784354026
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010894580055797673
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010876928861505882
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010859321057508746
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010841756500375686
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010824235047350236
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.001060511040413048
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00010952224484541209
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010934456453049954
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010916732104065616
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010899051293335703
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010881413877318093
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010863819712940773
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010846268657749465
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001082876057003461
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010811295308397854
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010793872732237954
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010776492701522825
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.001049333069896503
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00010906670409991173
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010889034378328173
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010871441516690714
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010853891683250058
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001083638473687934
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010818920537025017
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010801498943662467
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010784119817295115
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010766783019183941
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010749488410956472
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010732235854948521
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010715025213916402
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010697856351369467
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010680729131202008
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010663643417960743
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010646599076722177
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010629595973101966
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010612633973241734
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0011744415619832325
# 迷路を解くのにかかったステップ数は6です
# 方策の変化量は0.00010770487421218194
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010753164429017081
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010735883628928446
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010718644883044026
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010701448054165064
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010684293005465938
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010667179600738243
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010650107704457054
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010633077181474923
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001061608789719188
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010599139717877917
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010582232509837898
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001056536614034969
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010548540477028044
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010531755388023568
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010515010742153524
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010498306408624446
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010481642257186355
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010465018158281603
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010448433982646228
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010431889601733406
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010415384887331111
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010398919711992853
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010382493948485685
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010366107470322766
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010349760151435669
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001033345186630067
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010317182489870923
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010300951897523197
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010284759965322778
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010268606569701147
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010252491587540644
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010236414896403097
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010220376374114881
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010204375899170934
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010188413350473852
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010172488607394087
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010156601549803773
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010140752058117666
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010124940013065548
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001010916529603726
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010093427788757277
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.0001007772737351715
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010062063933000305
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010046437350412149
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010030847509394022
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は0.00010015294293994753
# 迷路を解くのにかかったステップ数は4です
# 方策の変化量は9.999777588869628e-05
# 迷路を解くのにかかったステップ数は4です
# 変化量がイプシロンよりも小さくなりました。

# %%
# 最終的な方策を確認
np.set_printoptions(precision=3, suppress=True)  # 有効桁数3、指数表示しないという設定
print(pi)
# Out:
# [[0.    0.01  0.99  0.   ]
#  [0.    0.281 0.    0.719]
#  [0.    0.    0.422 0.578]
#  [0.011 0.979 0.01  0.   ]
#  [0.    0.    0.983 0.017]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.017 0.983 0.    0.   ]]

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 3) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 2.5 - int(state / 3)  # y座標は3で割った商を2.5から引く
    line.set_data(x, y)
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc4ed6be97fd042be929218bfabd917c1">
#     <br>
#     <input id="_anim_sliderc4ed6be97fd042be929218bfabd917c1" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc4ed6be97fd042be929218bfabd917c1.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc4ed6be97fd042be929218bfabd917c1.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc4ed6be97fd042be929218bfabd917c1" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc4ed6be97fd042be929218bfabd917c1";
#     var slider_id = "_anim_sliderc4ed6be97fd042be929218bfabd917c1";
#     var loop_select_id = "_anim_loop_selectc4ed6be97fd042be929218bfabd917c1";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4xLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvDW2N/gAAHI5JREFUeJzt3XtwVPX9//HXJruBJJsUfoKQiyYo\
# lRh+UiSBIdBKJSihDrWKUBMvhFi+WKm1EgfrlHr92bFoZLDyc2S+EMW7gnJxqiUFjAJWGoRiuVT5\
# fo1AwAIRhNyz2c/3jyV8CRKSQJLz2d3nYybjkD3ZvPMxeebk5OQclzHGCABgnQinBwAAnBmBBgBL\
# EWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgA\
# sBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSB\
# BgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBL\
# EWgAsBSBBgBLuZ0e4Fz06dNHqampTo8BIMSUl5fr8OHDTo9xUlAGOjU1VWVlZU6PASDEZGZmOj1C\
# CxziAABLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSB\
# BgBLEWgAsFRQXm7UZsYYVRyv0Ob9m7WpYpNKvyrVjkM7VOurlc/vU5O/SZERkXJHuBXtjlZ633SN\
# SRmjEUkjlJGYoaS4JLlcLqc/DAAWINCdwG/8WvPfa/T0357Whj0b5PP75In0qKqhSn7j/872Pr9P\
# Pr9Pdb46bdi7QR/v+1jeKK8amhrkifBo9MWjNWvkLGVfkq0IFz/kAOGKQJ+HI7VHtHjLYhV9XKTj\
# DcdV1VB18rFaX227n8dv/DpWf0ySVKc6vb/7fa3fs15xUXEqzCpUwZUF6h3du9PnB2A3ds/Owb5j\
# +5S3LE+JTyfqwQ8e1IGqAy3i3BmqGqp0oOqAHvzgQSU+nahblt2ifcf2der7AGA3At0Bxhgt2rJI\
# ac+m6a3tb6nOV6eaxpoufZ81jTWq89Xpze1vKu3ZNC3askjGmC59nwDsQKDbqeJYha5+8Wrd8949\
# qm6sls/4uvX9+4xP1Y3Vuue9e3T1i1er4lhFt75/AN2PQLdD8dZipT2bpg17N6i6sdrRWaobq7Vh\
# 7walLUhT8dZiR2cB0LUI9FkYY3Tv+/fqV3/+laoaq+Tzd+9ec2t8fp+qGqr0qz//SrP+MotDHkCI\
# ItCtaPI3KX95vhZ+urDLjzOfq5rGGj2/+XlNWzFNTf4mp8cB0Mk4ze4MjDEqWFGgpTuXWhvnZjWN\
# NXprx1uSpOLri/kjFyCEsAd9BrP+MkvLdi6zPs7NmiNduLrQ6VEAdCICfZrircVa+OlCx38Z2FHN\
# hzv4xSEQOgj0KSqOVejXf/510Ow5n66msUa/fu/XnIIHhAgCfYIxRnlv56muqc7pUc5Lva9et7x9\
# C2d2ACGAQJ+weOtibd6/2ZpT6c5Vo79RZfvLONQBhAACrcC1NZr/QjAUVDdW65737+FQBxDkCLSk\
# 2SWzVe+rd3qMTlXnq9PsktlOjwHgPIR9oI/UHtE7u97p9mtrdDWf36e3d72tI7VHnB4FwDkK+0Av\
# 3rI4ZC+KH+GK4Fg0EMRCs0zt5Dd+FX1c1Pmn1VVLelfSPEmPSXpS0ouS/uvE40bSOklPSfp/kool\
# HezcEaTAaXdFG4vOeFeXUHLo0CHdddddSk1NVY8ePdSvXz9lZ2erpKREkvT2229r/Pjx6tu3r1wu\
# lz744ANnBw4RZ1v3xsZG3X///RoyZIhiY2OVkJCgvLw87dmzx+mxg0pY/6n3mv9eo+MNxzv/id+Q\
# 1Cjpekn/R4Fgl0tq/j6wQdLHkn4m6QJJpZKWSLpbUo/OHeVYwzGt/XKtxl0yrnOf2

# %% [markdown]
# # summary
# - 大まかな流れとして以下のループである。
#     1. 一旦適当な値に方策を定義する。
#     2. 実験を行う
#     3. 行った実験の元に方策の引数thetaを更新する
#
# - 方策勾配法
#     - softmaxを使用する理由はパラメータが負の値になっても方策を導出できるためである。
#     - 方策勾配定理を近似的に実装するのがreinforceである。
